# %% [markdown]
# # Contents
#
# #### 1. Import Libraries
# #### 2. Import Multiple files
#     Uderstanding Layout
#     Append and Cleaning
# #### 2. Adding additional file #1
#     Creating Country List
#     Merging with main df
# #### 3. Adding additional file #2
#     Cleaning
#     Merging with main df

# %% [markdown]
# # 1. Import Libaries

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r"C:\Users\Azalia\Documents\Projects\Self-Study\CareerFoundry\Education Completion Analysis"

# %% [markdown]
# # 2. Import multiple files

# %% [markdown]
# ##### Importing files for school completion rates and out of scgool rates for primary, lower secondary and upper secondary level. This is to prepare for concatenating the files.

# %%
df_compl_prim = pd.read_csv(os.path.join(path,'02 Data','Original Data','unicefEDUCATION_2012-2022 long format completion primary.csv'))
df_compl_lowsec = pd.read_csv(os.path.join(path,'02 Data','Original Data','unicefEDUCATION_2012-2022 long format completion lower second.csv'))
df_compl_upsec = pd.read_csv(os.path.join(path,'02 Data','Original Data','unicefEDUCATION_2012-2022 long format completion upper second.csv'))
df_out_prim = pd.read_csv(os.path.join(path,'02 Data','Original Data','unicefEDUCATION_2012-2022 long format outschool primary.csv'))
df_out_lowsec = pd.read_csv(os.path.join(path,'02 Data','Original Data','unicefEDUCATION_2012-2022 long format outschool lower second.csv'))
df_out_upsec = pd.read_csv(os.path.join(path,'02 Data','Original Data','unicefEDUCATION_2012-2022 long format outschool upper second.csv'))

# %%
df_compl_prim.shape
# Out:
# (1128, 19)

# %%
df_compl_lowsec.shape
# Out:
# (352, 21)

# %%
df_compl_upsec.shape
# Out:
# (352, 21)

# %%
df_out_prim.shape
# Out:
# (486, 21)

# %%
df_out_lowsec.shape
# Out:
# (490, 21)

# %%
df_out_upsec.shape
# Out:
# (536, 21)

# %% [markdown]
# ### understanding the data layout

# %% [markdown]
# ###### Checking for column details

# %%
df_compl_prim.columns
# Out:
# Index(['Geographic area', 'Indicator', 'Sex', 'Education Level',
#        'Wealth Quintile', 'Residence', 'Unit of measure', 'Unit multiplier',
#        'SOURCE_LINK', 'SERIES_FOOTNOTE', 'TIME_PERIOD', 'OBS_VALUE',
#        'Observation Status', 'DATA_SOURCE', 'Observation confidentaility',
#        'Time period activity related to when the data are collected',
#        'COVERAGE_TIME', 'OBS_FOOTNOTE',
#        'Time interval at which the source data are collected'],
#       dtype='object')

# %%
df_compl_lowsec.columns
# Out:
# Index(['Geographic area', 'Indicator', 'Sex', 'TIME_PERIOD', 'OBS_VALUE',
#        'Unit multiplier', 'Unit of measure', 'Observation Status',
#        'Observation confidentaility', 'LOWER_BOUND', 'UPPER_BOUND',
#        'WGTD_SAMPL_SIZE', 'OBS_FOOTNOTE', 'SERIES_FOOTNOTE', 'DATA_SOURCE',
#        'SOURCE_LINK', 'CUSTODIAN',
#        'Time period activity related to when the data are collected',
#        'REF_PERIOD', 'COVERAGE_TIME', 'Current age'],
#       dtype='object')

# %%
df_compl_prim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1128 entries, 0 to 1127
# Data columns (total 19 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Geographic area                                              1127 non-null   object
#  1   Indicator                                                    1127 non-null   object
#  2   Sex                                                          1127 non-null   object
#  3   Education Level                                              1127 non-null   object
#  4   Wealth Quintile                                              1127 non-null   object
#  5   Residence                                                    1127 non-null   object
#  6   Unit of measure                                              1127 non-null   object
# ...

# %%
df_compl_prim.head()
# Out:
#   Geographic area                                          Indicator     Sex  \
# 0     Afghanistan  Completion rate for children of primary school...  Female
# 1     Afghanistan  Completion rate for children of primary school...    Male
# 2     Afghanistan  Completion rate for children of primary school...   Total
# 3     Afghanistan  Completion rate for children of primary school...   Total
# 4     Afghanistan  Completion rate for children of primary school...   Total
#
#      Education Level Wealth Quintile Residence Unit of measure  \
# 0  Primary education           Total     Total               %
# 1  Primary education           Total     Total               %
# 2  Primary education          Lowest     Total               %
# 3  Primary education          Second     Total               %
# 4  Primary education          Middle     Total               %
#
#    Unit multiplier  SOURCE_LINK  SERIES_FOOTNOTE  TIME_PERIOD  OBS_VALUE  \
# ...

# %%
df_out_lowsec.columns
# Out:
# Index(['Geographic area', 'Indicator', 'Sex', 'TIME_PERIOD', 'OBS_VALUE',
#        'Unit multiplier', 'Unit of measure', 'Observation Status',
#        'Observation confidentaility', 'LOWER_BOUND', 'UPPER_BOUND',
#        'WGTD_SAMPL_SIZE', 'OBS_FOOTNOTE', 'SERIES_FOOTNOTE', 'DATA_SOURCE',
#        'SOURCE_LINK', 'CUSTODIAN',
#        'Time period activity related to when the data are collected',
#        'REF_PERIOD', 'COVERAGE_TIME', 'Current age'],
#       dtype='object')

# %%
df_out_upsec.head()
# Out:
#   Geographic area                                          Indicator     Sex  \
# 0     Afghanistan  Out-of-school rate for youth of upper secondar...  Female
# 1     Afghanistan  Out-of-school rate for youth of upper secondar...    Male
# 2     Afghanistan  Out-of-school rate for youth of upper secondar...   Total
# 3         Albania  Out-of-school rate for youth of upper secondar...  Female
# 4         Albania  Out-of-school rate for youth of upper secondar...    Male
#
#    TIME_PERIOD  OBS_VALUE  Unit multiplier Unit of measure  \
# 0       2018.0   68.68825              NaN               %
# 1       2018.0   43.78052              NaN               %
# 2       2018.0   55.89854              NaN               %
# 3       2020.0   15.10066              NaN               %
# 4       2020.0   21.92466              NaN               %
#
#    Observation Status  Observation confidentaility  LOWER_BOUND  ...  \
# 0                 NaN                          NaN          NaN  ...
# ...

# %%
df_out_upsec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536 entries, 0 to 535
# Data columns (total 21 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Geographic area                                              535 non-null    object
#  1   Indicator                                                    535 non-null    object
#  2   Sex                                                          535 non-null    object
#  3   TIME_PERIOD                                                  535 non-null    float64
#  4   OBS_VALUE                                                    535 non-null    float64
#  5   Unit multiplier                                              0 non-null      float64
#  6   Unit of measure                                              535 non-null    object
# ...

# %%
df_out_prim.shape
# Out:
# (486, 21)

# %% [markdown]
# ### Appending all related files

# %% [markdown]
# ##### appending files using pd's concat method and using frames to combine multiple dfs

# %%
frames = [df_compl_prim,df_compl_upsec,df_compl_lowsec,df_out_prim,df_out_lowsec,df_out_upsec]

# %%
frames
# Out:
# [     Geographic area                                          Indicator  \
#  0        Afghanistan  Completion rate for children of primary school...
#  1        Afghanistan  Completion rate for children of primary school...
#  2        Afghanistan  Completion rate for children of primary school...
#  3        Afghanistan  Completion rate for children of primary school...
#  4        Afghanistan  Completion rate for children of primary school...
#  ...              ...                                                ...
#  1123          Kosovo  Completion rate for children of primary school...
#  1124          Kosovo  Completion rate for children of primary school...
#  1125          Kosovo  Completion rate for children of primary school...
#  1126          Kosovo  Completion rate for children of primary school...
#  1127             NaN                                                NaN
#
#           Sex    Education Level Wealth Quintile Residence Unit of measure  \
# ...

# %%
type(frames)
# Out:
# list

# %%
df_concat = pd.concat(frames)

# %%
df_concat
# Out:
#     Geographic area                                          Indicator  \
# 0       Afghanistan  Completion rate for children of primary school...
# 1       Afghanistan  Completion rate for children of primary school...
# 2       Afghanistan  Completion rate for children of primary school...
# 3       Afghanistan  Completion rate for children of primary school...
# 4       Afghanistan  Completion rate for children of primary school...
# ..              ...                                                ...
# 531           Yemen  Out-of-school rate for youth of upper secondar...
# 532        Zimbabwe  Out-of-school rate for youth of upper secondar...
# 533        Zimbabwe  Out-of-school rate for youth of upper secondar...
# 534        Zimbabwe  Out-of-school rate for youth of upper secondar...
# 535             NaN                                                NaN
#
#         Sex    Education Level Wealth Quintile Residence Unit of measure  \
# ...

# %%
df_concat.shape
# Out:
# (3344, 25)

# %%
df_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3344 entries, 0 to 535
# Data columns (total 25 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Geographic area                                              3338 non-null   object
#  1   Indicator                                                    3338 non-null   object
#  2   Sex                                                          3338 non-null   object
#  3   Education Level                                              1127 non-null   object
#  4   Wealth Quintile                                              1127 non-null   object
#  5   Residence                                                    1127 non-null   object
#  6   Unit of measure                                              3338 non-null   object
# ...

# %% [markdown]
# ### Cleaning and Checking Data

# %% [markdown]
# ##### removing null or non useful columns

# %%
df_concat_del = df_concat.drop(columns=['Unit multiplier','SOURCE_LINK','SERIES_FOOTNOTE','Observation Status','Observation confidentaility','Time period activity related to when the data are collected','COVERAGE_TIME','OBS_FOOTNOTE','LOWER_BOUND','UPPER_BOUND','WGTD_SAMPL_SIZE','CUSTODIAN','REF_PERIOD'])

# %%
df_concat_del.head(20)
# Out:
#    Geographic area                                          Indicator     Sex  \
# 0      Afghanistan  Completion rate for children of primary school...  Female
# 1      Afghanistan  Completion rate for children of primary school...    Male
# 2      Afghanistan  Completion rate for children of primary school...   Total
# 3      Afghanistan  Completion rate for children of primary school...   Total
# 4      Afghanistan  Completion rate for children of primary school...   Total
# 5      Afghanistan  Completion rate for children of primary school...   Total
# 6      Afghanistan  Completion rate for children of primary school...   Total
# 7      Afghanistan  Completion rate for children of primary school...   Total
# 8      Afghanistan  Completion rate for children of primary school...   Total
# 9      Afghanistan  Completion rate for children of primary school...   Total
# 10          Angola  Completion rate for children of primary school...  Female
# ...

# %%
#Checking if 'Time interval at which the source data are collected' is useful
df_concat_del['Time interval at which the source data are collected'].value_counts(dropna=False)
# Out:
# NaN          2493
# Not Known     851
# Name: Time interval at which the source data are collected, dtype: int64

# %%
#Checking if 'Current age' column is useful
df_concat_del['Current age'].value_counts(dropna=False)
# Out:
# Total    2211
# NaN      1133
# Name: Current age, dtype: int64

# %%
#Checking if 'Unit of measure' column is useful
df_concat_del['Unit of measure'].value_counts(dropna=False)
# Out:
# %      3338
# NaN       6
# Name: Unit of measure, dtype: int64

# %%
#removing the above columns because it contains no useful data
df_concat_del2 = df_concat_del.drop(columns=['Time interval at which the source data are collected','Current age','Unit of measure'])

# %%
df_concat_del2.shape
# Out:
# (3344, 9)

# %%
df_concat_del2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3344 entries, 0 to 535
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic area  3338 non-null   object
#  1   Indicator        3338 non-null   object
#  2   Sex              3338 non-null   object
#  3   Education Level  1127 non-null   object
#  4   Wealth Quintile  1127 non-null   object
#  5   Residence        1127 non-null   object
#  6   TIME_PERIOD      3338 non-null   float64
#  7   OBS_VALUE        3338 non-null   float64
#  8   DATA_SOURCE      3338 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 261.2+ KB

# %% [markdown]
# ### Rename columns

# %%
df_concat_del2.rename(columns={'Geographic area':'Country','Sex':'Gender','Education Level':'Education_Level','Wealth Quintile':'Wealth_Quintile','TIME_PERIOD':'Data_Year','OBS_VALUE':'Percentage','DATA_SOURCE':'Data_Source'}, inplace=True)

# %%
print(df_concat_del2.columns)
# Out:
# Index(['Country', 'Indicator', 'Gender', 'Education_Level', 'Wealth_Quintile',
#        'Residence', 'Data_Year', 'Percentage', 'Data_Source'],
#       dtype='object')

# %% [markdown]
# ### Checking for missing values

# %%
# Finding missing values
df_concat_del2.isnull().sum()
# Out:
# Country               6
# Indicator             6
# Gender                6
# Education_Level    2217
# Wealth_Quintile    2217
# Residence          2217
# Data_Year             6
# Percentage            6
# Data_Source           6
# dtype: int64

# %%
#View subset for missing Indicator values
df_ind_nan = df_concat_del2[df_concat_del2['Indicator'].isnull()==True]
df_ind_nan
# Out:
#      Country Indicator Gender Education_Level Wealth_Quintile Residence  \
# 1127     NaN       NaN    NaN             NaN             NaN       NaN
# 351      NaN       NaN    NaN             NaN             NaN       NaN
# 351      NaN       NaN    NaN             NaN             NaN       NaN
# 485      NaN       NaN    NaN             NaN             NaN       NaN
# 489      NaN       NaN    NaN             NaN             NaN       NaN
# 535      NaN       NaN    NaN             NaN             NaN       NaN
#
#       Data_Year  Percentage Data_Source
# 1127        NaN         NaN         NaN
# 351         NaN         NaN         NaN
# 351         NaN         NaN         NaN
# 485         NaN         NaN         NaN
# 489         NaN         NaN         NaN
# 535         NaN         NaN         NaN

# %%
#Drop missing values & empty rows
df_concat_del2_dropnan = df_concat_del2[df_concat_del2['Indicator'].isnull() == False]
df_concat_del2_dropnan.shape
# Out:
# (3338, 9)

# %% [markdown]
# ### Cheking duplicates

# %%
df_dup = df_concat_del2_dropnan[df_concat_del2_dropnan.duplicated()]
df_dup
# Out:
# Empty DataFrame
# Columns: [Country, Indicator, Gender, Education_Level, Wealth_Quintile, Residence, Data_Year, Percentage, Data_Source]
# Index: []

# %% [markdown]
# ### Column by column check

# %% [markdown]
# #### Indicator Column check

# %%
df_concat_del2_dropnan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3338 entries, 0 to 534
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          3338 non-null   object
#  1   Indicator        3338 non-null   object
#  2   Gender           3338 non-null   object
#  3   Education_Level  1127 non-null   object
#  4   Wealth_Quintile  1127 non-null   object
#  5   Residence        1127 non-null   object
#  6   Data_Year        3338 non-null   float64
#  7   Percentage       3338 non-null   float64
#  8   Data_Source      3338 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 260.8+ KB

# %%
#Checking value counts for Indicator column
df_concat_del2_dropnan['Indicator'].value_counts(dropna=False)
# Out:
# Completion rate for children of primary school age                                        1127
# Out-of-school rate for youth of upper secondary school age (administrative data)           535
# Out-of-school rate for adolescents of lower secondary school age (administrative data)     489
# Out-of-school rate for children of primary school age (administrative data)                485
# Completion rate for youth of upper secondary education school age                          351
# Completion rate for adolescents of lower secondary school age                              351
# Name: Indicator, dtype: int64

# %%
#Rename indicator values
df_concat_del2_dropnan['Indicator']=df_concat_del2_dropnan['Indicator'].replace(['Out-of-school rate for youth of upper secondary school age (administrative data)','Out-of-school rate for adolescents of lower secondary school age (administrative data)','Out-of-school rate for children of primary school age (administrative data)'],['Out-of-school rate for youth of upper secondary school age','Out-of-school rate for adolescents of lower secondary school age','Out-of-school rate for children of primary school age'])
# Out:
# C:\Users\Azalia\AppData\Local\Temp\ipykernel_108392\1815237996.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_concat_del2_dropnan['Indicator']=df_concat_del2_dropnan['Indicator'].replace(['Out-of-school rate for youth of upper secondary school age (administrative data)','Out-of-school rate for adolescents of lower secondary school age (administrative data)','Out-of-school rate for children of primary school age (administrative data)'],['Out-of-school rate for youth of upper secondary school age','Out-of-school rate for adolescents of lower secondary school age','Out-of-school rate for children of primary school age'])

# %%
df_concat_del2_dropnan['Indicator'].value_counts(dropna=False)
# Out:
# Completion rate for children of primary school age                   1127
# Out-of-school rate for youth of upper secondary school age            535
# Out-of-school rate for adolescents of lower secondary school age      489
# Out-of-school rate for children of primary school age                 485
# Completion rate for youth of upper secondary education school age     351
# Completion rate for adolescents of lower secondary school age         351
# Name: Indicator, dtype: int64

# %% [markdown]
# #### Country column check

# %%
#Continue Checking value counts for column variables
df_concat_del2_dropnan['Country'].value_counts(dropna=False)
# Out:
# Middle East and North Africa    25
# West and Central Africa         25
# Niger                           25
# Mauritania                      25
# Mongolia                        25
#                                 ..
# Tokelau                          3
# Trinidad and Tobago              3
# Palau                            2
# Anguilla                         2
# Niue                             1
# Name: Country, Length: 207, dtype: int64

# %%
# Countries contain aggregated values. To view subset of these aggregated values
df_concat_del2_agg = df_concat_del2_dropnan.loc[df_concat_del2_dropnan['Country'].isin(['East Asia and Pacific', 'Europe and Central Asia', 'Eastern Europe and Central Asia', 'Western Europe','Latin America and Caribbean', 'Middle East and North Africa','North America','South Asia','Sub-Saharan Africa', 'Eastern and Southern Africa', 'West and Central Africa', 'Least developed countries', 'World'
])]

# %%
df_concat_del2_agg
# Out:
#                    Country                                          Indicator  \
# 954  East Asia and Pacific  Completion rate for children of primary school...
# 955  East Asia and Pacific  Completion rate for children of primary school...
# 956  East Asia and Pacific  Completion rate for children of primary school...
# 957  East Asia and Pacific  Completion rate for children of primary school...
# 958  East Asia and Pacific  Completion rate for children of primary school...
# ..                     ...                                                ...
# 524         Western Europe  Out-of-school rate for youth of upper secondar...
# 525         Western Europe  Out-of-school rate for youth of upper secondar...
# 526                  World  Out-of-school rate for youth of upper secondar...
# 527                  World  Out-of-school rate for youth of upper secondar...
# 528                  World  Out-of-school rate for youth of upper secondar...
#
# ...

# %%
# creating df of this inverse list
df_concat_del2_clean_ctry = df_concat_del2_dropnan[~(df_concat_del2_dropnan["Country"].isin(['East Asia and Pacific', 'Europe and Central Asia', 'Eastern Europe and Central Asia', 'Western Europe','Latin America and Caribbean', 'Middle East and North Africa','North America','South Asia','Sub-Saharan Africa', 'Eastern and Southern Africa', 'West and Central Africa', 'Least developed countries', 'World']))]

# %%
df_concat_del2_clean_ctry.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3068 entries, 0 to 534
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          3068 non-null   object
#  1   Indicator        3068 non-null   object
#  2   Gender           3068 non-null   object
#  3   Education_Level  1034 non-null   object
#  4   Wealth_Quintile  1034 non-null   object
#  5   Residence        1034 non-null   object
#  6   Data_Year        3068 non-null   float64
#  7   Percentage       3068 non-null   float64
#  8   Data_Source      3068 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 239.7+ KB

# %%
df_concat_del2_clean_ctry['Country'].value_counts(dropna=False)
# Out:
# Uganda                 25
# Türkiye                25
# Lesotho                25
# Sri Lanka              25
# Saint Lucia            25
#                        ..
# Tokelau                 3
# Trinidad and Tobago     3
# Palau                   2
# Anguilla                2
# Niue                    1
# Name: Country, Length: 194, dtype: int64

# %% [markdown]
# #### Gender Column check

# %%
df_concat_del2_clean_ctry['Gender'].value_counts(dropna=False)
# Out:
# Total     1534
# Female     767
# Male       767
# Name: Gender, dtype: int64

# %%
# Create subset of Gender totals using loc
df_gender_tot = df_concat_del2_clean_ctry.loc[df_concat_del2_clean_ctry['Gender']=='Total']
df_gender_tot
# Out:
#                                 Country  \
# 2                           Afghanistan
# 3                           Afghanistan
# 4                           Afghanistan
# 5                           Afghanistan
# 6                           Afghanistan
# ..                                  ...
# 513                          Uzbekistan
# 516                             Vanuatu
# 519  Venezuela (Bolivarian Republic of)
# 531                               Yemen
# 534                            Zimbabwe
#
#                                              Indicator Gender  \
# 2    Completion rate for children of primary school...  Total
# 3    Completion rate for children of primary school...  Total
# 4    Completion rate for children of primary school...  Total
# 5    Completion rate for children of primary school...  Total
# 6    Completion rate for children of primary school...  Total
# ..                                                 ...    ...
# ...

# %%
# Export dataset for future use
df_gender_tot.to_csv(os.path.join(path,'02 Data','Prepared Data', 'Gender Totals.csv'))

# %%
# Create inverse list of Gender totals
df_concat_del2_clean_gender = df_concat_del2_clean_ctry[~df_concat_del2_clean_ctry['Gender'].isin(['Total'])]
df_concat_del2_clean_gender
# Out:
#                                 Country  \
# 0                           Afghanistan
# 1                           Afghanistan
# 10                               Angola
# 11                               Angola
# 20                              Albania
# ..                                  ...
# 518  Venezuela (Bolivarian Republic of)
# 529                               Yemen
# 530                               Yemen
# 532                            Zimbabwe
# 533                            Zimbabwe
#
#                                              Indicator  Gender  \
# 0    Completion rate for children of primary school...  Female
# 1    Completion rate for children of primary school...    Male
# 10   Completion rate for children of primary school...  Female
# 11   Completion rate for children of primary school...    Male
# 20   Completion rate for children of primary school...  Female
# ..                                                 ...     ...
# ...

# %% [markdown]
# #### Checking Education Level column

# %%
df_concat_del2_clean_gender['Education_Level'].value_counts(dropna=False)
# Out:
# NaN                  1320
# Primary education     214
# Name: Education_Level, dtype: int64

# %% [markdown]
# #### impute values into education level based on Indicator (alternative code)
# df_concat_del2_clean_gender.loc[(df_concat_del2_clean_gender['Indicator']=='Out-of-school rate for youth of upper secondary school age')&(df_concat_del2_clean_gender['Indicator']=='Completion rate for youth of upper secondary education school age'),'Education_Level']='Upper Secondary'

# %%
#impute values into education level based on Indicator using loops
result = []
for value in df_concat_del2_clean_gender['Indicator']:
    if value in ['Completion rate for children of primary school age','Out-of-school rate for children of primary school age']:
        result.append ('Primary')
    elif value in ['Completion rate for youth of upper secondary education school age','Out-of-school rate for youth of upper secondary school age']:
        result.append ('Upper Secondary')
    else:
        result.append ('Lower Secondary')

# %%
df_concat_del2_clean_gender['Education_Level'] = result
# Out:
# C:\Users\Azalia\AppData\Local\Temp\ipykernel_108392\2980591133.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_concat_del2_clean_gender['Education_Level'] = result

# %%
df_concat_del2_clean_gender['Education_Level'].value_counts(dropna=False)
# Out:
# Upper Secondary    540
# Lower Secondary    504
# Primary            490
# Name: Education_Level, dtype: int64

# %% [markdown]
# #### Checking Wealth_Quintile column

# %%
df_concat_del2_clean_gender['Wealth_Quintile'].value_counts(dropna=False)
# Out:
# NaN      1320
# Total     214
# Name: Wealth_Quintile, dtype: int64

# %%
# Change Nan to Not Available
df_concat_del2_clean_gender['Wealth_Quintile'].fillna('Not Available', inplace=True)
# Out:
# C:\Users\Azalia\AppData\Local\Temp\ipykernel_108392\2015223961.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_concat_del2_clean_gender['Wealth_Quintile'].fillna('Not Available', inplace=True)

# %%
df_concat_del2_clean_gender['Wealth_Quintile'].value_counts(dropna=False)
# Out:
# Not Available    1320
# Total             214
# Name: Wealth_Quintile, dtype: int64

# %%
df_concat_del2_clean_gender
# Out:
#                                 Country  \
# 0                           Afghanistan
# 1                           Afghanistan
# 10                               Angola
# 11                               Angola
# 20                              Albania
# ..                                  ...
# 518  Venezuela (Bolivarian Republic of)
# 529                               Yemen
# 530                               Yemen
# 532                            Zimbabwe
# 533                            Zimbabwe
#
#                                              Indicator  Gender  \
# 0    Completion rate for children of primary school...  Female
# 1    Completion rate for children of primary school...    Male
# 10   Completion rate for children of primary school...  Female
# 11   Completion rate for children of primary school...    Male
# 20   Completion rate for children of primary school...  Female
# ..                                                 ...     ...
# ...

# %% [markdown]
# #### Checking Residence Column

# %%
df_concat_del2_clean_gender['Residence'].value_counts(dropna=False)
# Out:
# NaN      1320
# Total     214
# Name: Residence, dtype: int64

# %%
# Change Nan to Not Available
df_concat_del2_clean_gender['Residence'].fillna('Not Available', inplace=True)
# Out:
# C:\Users\Azalia\AppData\Local\Temp\ipykernel_108392\2296576208.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_concat_del2_clean_gender['Residence'].fillna('Not Available', inplace=True)

# %%
df_concat_del2_clean_gender
# Out:
#                                 Country  \
# 0                           Afghanistan
# 1                           Afghanistan
# 10                               Angola
# 11                               Angola
# 20                              Albania
# ..                                  ...
# 518  Venezuela (Bolivarian Republic of)
# 529                               Yemen
# 530                               Yemen
# 532                            Zimbabwe
# 533                            Zimbabwe
#
#                                              Indicator  Gender  \
# 0    Completion rate for children of primary school...  Female
# 1    Completion rate for children of primary school...    Male
# 10   Completion rate for children of primary school...  Female
# 11   Completion rate for children of primary school...    Male
# 20   Completion rate for children of primary school...  Female
# ..                                                 ...     ...
# ...

# %%
df_concat_del2_clean_gender['Residence'].value_counts(dropna=False)
# Out:
# Not Available    1320
# Total             214
# Name: Residence, dtype: int64

# %% [markdown]
# #### Checking Data_Year column

# %%
df_concat_del2_clean_gender['Data_Year'].value_counts(dropna=False)
# Out:
# 2019.0    398
# 2020.0    318
# 2018.0    216
# 2017.0    142
# 2016.0    128
# 2015.0    116
# 2014.0     86
# 2012.0     54
# 2013.0     42
# 2021.0     28
# 2022.0      6
# Name: Data_Year, dtype: int64

# %%
# changing data type to int
df_concat_del2_clean_gender['Data_Year']=df_concat_del2_clean_gender['Data_Year'].astype('int32')
# Out:
# C:\Users\Azalia\AppData\Local\Temp\ipykernel_108392\2401455039.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_concat_del2_clean_gender['Data_Year']=df_concat_del2_clean_gender['Data_Year'].astype('int32')

# %%
df_concat_del2_clean_gender['Data_Year']=df_concat_del2_clean_gender['Data_Year'].astype('str')
# Out:
# C:\Users\Azalia\AppData\Local\Temp\ipykernel_108392\4243457454.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_concat_del2_clean_gender['Data_Year']=df_concat_del2_clean_gender['Data_Year'].astype('str')

# %%
df_concat_del2_clean_gender['Data_Year'].value_counts(dropna=False)
# Out:
# 2019    398
# 2020    318
# 2018    216
# 2017    142
# 2016    128
# 2015    116
# 2014     86
# 2012     54
# 2013     42
# 2021     28
# 2022      6
# Name: Data_Year, dtype: int64

# %% [markdown]
# #### Checking Percentage column

# %%
df_concat_del2_clean_gender['Percentage'].value_counts(dropna=False)
# Out:
# 100.000000    11
# 0.000000       6
# 99.900002      3
# 96.900002      3
# 99.000000      3
#               ..
# 53.450909      1
# 40.193409      1
# 35.799999      1
# 25.100000      1
# 40.338200      1
# Name: Percentage, Length: 1480, dtype: int64

# %% [markdown]
# #### Checking Data_Source Column

# %%
df_concat_del2_clean_gender['Data_Source'].value_counts(dropna=False)
# Out:
# UIS                                            892
# MICS 2019                                       84
# MICS 2018                                       54
# MICS 2019-20                                    42
# DHS 2016                                        30
# DHS 2015-16                                     28
# DHS 2018                                        24
# DHS 2017-18                                     24
# MICS 2014                                       24
# DHS 2013                                        24
# MICS 2012                                       24
# MICS 2018-19                                    24
# DHS 2012                                        24
# MICS 2017                                       22
# DHS 2015                                        20
# MICS 2015                                       18
# DHS 2014                                        18
# DHS 2017                                        18
# ...

# %% [markdown]
# ### Changing Column types

# %%
df_concat_del2_clean_gender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1534 entries, 0 to 533
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          1534 non-null   object
#  1   Indicator        1534 non-null   object
#  2   Gender           1534 non-null   object
#  3   Education_Level  1534 non-null   object
#  4   Wealth_Quintile  1534 non-null   object
#  5   Residence        1534 non-null   object
#  6   Data_Year        1534 non-null   object
#  7   Percentage       1534 non-null   float64
#  8   Data_Source      1534 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 119.8+ KB

# %% [markdown]
# df_concat_del2_clean_gender['Country']=df_concat_del2['Country'].astype('str')
# df_concat_del2_clean_gender['Indicator']=df_concat_del2['Indicator'].astype('str')
# df_concat_del2_clean_gender['Education_Level']=df_concat_del2['Education_Level'].astype('category')
# df_concat_del2_clean_gender['Wealth_Quintile']=df_concat_del2['Wealth_Quintile'].astype('category')
# df_concat_del2_clean_gender['Residence']=df_concat_del2['Residence'].astype('category')

# %%
#checking 1st country subset data
df_filter_afghan = df_concat_del2_clean_gender[df_concat_del2_clean_gender['Country']=='Afghanistan']
df_filter_afghan
# Out:
#        Country                                          Indicator  Gender  \
# 0  Afghanistan  Completion rate for children of primary school...  Female
# 1  Afghanistan  Completion rate for children of primary school...    Male
# 0  Afghanistan  Completion rate for youth of upper secondary e...  Female
# 1  Afghanistan  Completion rate for youth of upper secondary e...    Male
# 0  Afghanistan  Completion rate for adolescents of lower secon...  Female
# 1  Afghanistan  Completion rate for adolescents of lower secon...    Male
# 0  Afghanistan  Out-of-school rate for youth of upper secondar...  Female
# 1  Afghanistan  Out-of-school rate for youth of upper secondar...    Male
#
#    Education_Level Wealth_Quintile      Residence Data_Year  Percentage  \
# 0          Primary           Total          Total      2015   40.200001
# 1          Primary           Total          Total      2015   67.199997
# 0  Upper Secondary   Not Available  Not Available      2015   14.365360
# ...

# %% [markdown]
# # 2. Adding additional file #1

# %%
# download file on Happines ranking
df_happy = pd.read_csv(os.path.join(path,'02 Data','Original Data','2022 Happiness Index.csv'))

# %%
df_happy.head()
# Out:
#    RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0     1      Finland            7.821         7.886        7.756
# 1     2      Denmark            7.636         7.710        7.563
# 2     3      Iceland            7.557         7.651        7.464
# 3     4  Switzerland            7.512         7.586        7.437
# 4     5  Netherlands            7.415         7.471        7.359
#
#    Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                       2.518                         1.892
# 1                       2.226                         1.953
# 2                       2.320                         1.936
# 3                       2.153                         2.026
# 4                       2.137                         1.945
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.258                                  0.775
# ...

# %%
df_happy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 12 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   RANK                                        147 non-null    int64
#  1   Country                                     147 non-null    object
#  2   Happiness score                             146 non-null    float64
#  3   Whisker-high                                146 non-null    float64
#  4   Whisker-low                                 146 non-null    float64
#  5   Dystopia (1.83) + residual                  146 non-null    float64
#  6   Explained by: GDP per capita                146 non-null    float64
#  7   Explained by: Social support                146 non-null    float64
#  8   Explained by: Healthy life expectancy       146 non-null    float64
# ...

# %% [markdown]
# #### Performing Cleaning on file

# %%
#find missing values
df_happy.isnull().sum()
# Out:
# RANK                                          0
# Country                                       0
# Happiness score                               1
# Whisker-high                                  1
# Whisker-low                                   1
# Dystopia (1.83) + residual                    1
# Explained by: GDP per capita                  1
# Explained by: Social support                  1
# Explained by: Healthy life expectancy         1
# Explained by: Freedom to make life choices    1
# Explained by: Generosity                      1
# Explained by: Perceptions of corruption       1
# dtype: int64

# %%
df_happy_nan = df_happy[df_happy['Happiness score'].isnull()==True]

# %%
df_happy_nan
# Out:
#      RANK Country  Happiness score  Whisker-high  Whisker-low  \
# 146   147      xx              NaN           NaN          NaN
#
#      Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 146                         NaN                           NaN
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 146                           NaN                                    NaN
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 146                                         NaN                       NaN
#
#      Explained by: Perceptions of corruption
# 146                                      NaN

# %%
# delete missing value row
df_happy.dropna(subset=['Happiness score'],inplace = True)

# %%
df_happy.isnull().sum()
# Out:
# RANK                                          0
# Country                                       0
# Happiness score                               0
# Whisker-high                                  0
# Whisker-low                                   0
# Dystopia (1.83) + residual                    0
# Explained by: GDP per capita                  0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# dtype: int64

# %%
df_happy.head()
# Out:
#    RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0     1      Finland            7.821         7.886        7.756
# 1     2      Denmark            7.636         7.710        7.563
# 2     3      Iceland            7.557         7.651        7.464
# 3     4  Switzerland            7.512         7.586        7.437
# 4     5  Netherlands            7.415         7.471        7.359
#
#    Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                       2.518                         1.892
# 1                       2.226                         1.953
# 2                       2.320                         1.936
# 3                       2.153                         2.026
# 4                       2.137                         1.945
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.258                                  0.775
# ...

# %% [markdown]
# #### Deleting columns

# %%
# keep only country rank
df_happyrank = df_happy.drop(columns=['Happiness score','Whisker-high','Whisker-low','Dystopia (1.83) + residual','Explained by: GDP per capita','Explained by: Social support','Explained by: Healthy life expectancy','Explained by: Freedom to make life choices','Explained by: Generosity','Explained by: Perceptions of corruption'
])

# %%
df_happyrank.head()
# Out:
#    RANK      Country
# 0     1      Finland
# 1     2      Denmark
# 2     3      Iceland
# 3     4  Switzerland
# 4     5  Netherlands

# %%
df_happyrank['Country'].value_counts(dropna=False)
# Out:
# Finland        1
# Iran           1
# Bangladesh     1
# Laos           1
# Algeria        1
#               ..
# Kuwait*        1
# Hungary        1
# Mauritius      1
# Uzbekistan     1
# Afghanistan    1
# Name: Country, Length: 146, dtype: int64

# %% [markdown]
# #### Creating a country names list as reference

# %%
# Getting country list names based on UNICEF list
ctrylist = df_concat_del2_clean_ctry['Country'].unique()
ctrylist
# Out:
# array(['Afghanistan', 'Angola', 'Albania', 'Argentina', 'Armenia',
#        'Burundi', 'Benin', 'Bangladesh', 'Bosnia and Herzegovina',
#        'Belarus', 'Belize', 'Bolivia (Plurinational State of)', 'Brazil',
#        'Barbados', 'Botswana', 'Central African Republic', 'Chile',
#        'China', "Côte d'Ivoire", 'Cameroon',
#        'Democratic Republic of the Congo', 'Congo', 'Colombia', 'Comoros',
#        'Costa Rica', 'Cuba', 'Dominican Republic', 'Algeria', 'Ecuador',
#        'Egypt', 'Ethiopia', 'Gabon', 'Georgia', 'Ghana', 'Guinea',
#        'Gambia', 'Guinea-Bissau', 'Guatemala', 'Guyana', 'Honduras',
#        'Haiti', 'Indonesia', 'India', 'Iraq', 'Jordan', 'Kazakhstan',
#        'Kenya', 'Kyrgyzstan', 'Cambodia', 'Kiribati',
#        "Lao People's Democratic Republic", 'Liberia', 'Saint Lucia',
#        'Sri Lanka', 'Lesotho', 'Republic of Moldova', 'Madagascar',
#        'Mexico', 'North Macedonia', 'Mali', 'Myanmar', 'Montenegro',
# ...

# %%
# Creating a country list df as reference
df_ctrylist = pd.DataFrame(ctrylist, columns=['Country'])
df_ctrylist
# Out:
#                                 Country
# 0                           Afghanistan
# 1                                Angola
# 2                               Albania
# 3                             Argentina
# 4                               Armenia
# ..                                  ...
# 189                             Vanuatu
# 190  Venezuela (Bolivarian Republic of)
# 191                                Niue
# 192                             Tokelau
# 193                 Trinidad and Tobago
#
# [194 rows x 1 columns]

# %%
# exporting countrylist for info
df_ctrylist.to_csv(os.path.join(path, '02 Data','Checking Data','Countrylist.csv'))

# %%
# merge df_happyrank countries with df_ctrylist. Outer merge to see full list and if cleaning needs to be done
df_merge_ctry = df_ctrylist.merge(df_happyrank, on = 'Country', how='outer', indicator=True)
df_merge_ctry
# Out:
#          Country   RANK      _merge
# 0    Afghanistan  146.0        both
# 1         Angola    NaN   left_only
# 2        Albania   90.0        both
# 3      Argentina   57.0        both
# 4        Armenia   82.0        both
# ..           ...    ...         ...
# 226     Tanzania  139.0  right_only
# 227     Lesotho*  141.0  right_only
# 228    Botswana*  142.0  right_only
# 229      Rwanda*  143.0  right_only
# 230      Lebanon  145.0  right_only
#
# [231 rows x 3 columns]

# %%
df_merge_ctry['_merge'].value_counts(dropna=False)
# Out:
# both          109
# left_only      85
# right_only     37
# Name: _merge, dtype: int64

# %%
# Find countries with * in df_happyrank
df_ctryastr = df_happyrank[df_happyrank['Country'].str.contains('\*')]
df_ctryastr
# Out:
#      RANK                   Country
# 5       6               Luxembourg*
# 38     39                Guatemala*
# 49     50                   Kuwait*
# 64     65                  Belarus*
# 77     78             Turkmenistan*
# 78     79             North Cyprus*
# 85     86                    Libya*
# 91     92               Azerbaijan*
# 92     93                   Gambia*
# 96     97                  Liberia*
# 103   104                    Niger*
# 115   116                  Comoros*
# 121   122  Palestinian Territories*
# 124   125     Eswatini, Kingdom of*
# 127   128               Madagascar*
# 129   130                     Chad*
# 131   132                    Yemen*
# 132   133               Mauritania*
# 140   141                  Lesotho*
# 141   142                 Botswana*
# 142   143                   Rwanda*

# %%
#turning valus into list for easy copy
df_ctryastr['Country'].values.tolist()
# Out:
# ['Luxembourg*',
#  'Guatemala*',
#  'Kuwait*',
#  'Belarus*',
#  'Turkmenistan*',
#  'North Cyprus*',
#  'Libya*',
#  'Azerbaijan*',
#  'Gambia*',
#  'Liberia*',
#  'Niger*',
#  'Comoros*',
#  'Palestinian Territories*',
#  'Eswatini, Kingdom of*',
#  'Madagascar*',
#  'Chad*',
#  'Yemen*',
#  'Mauritania*',
#  'Lesotho*',
#  'Botswana*',
#  'Rwanda*']

# %%
# to Rename and remove asterisk in this list
df_happyrank['Country'] = df_happyrank['Country'].replace(['Luxembourg*','Guatemala*', 'Kuwait*','Belarus*','Turkmenistan*','North Cyprus*','Libya*','Azerbaijan*','Gambia*','Liberia*','Niger*','Comoros*','Palestinian Territories*','Eswatini, Kingdom of*','Madagascar*','Chad*','Yemen*','Mauritania*','Lesotho*','Botswana*','Rwanda*'],['Luxembourg','Guatemala', 'Kuwait','Belarus','Turkmenistan','North Cyprus','Libya','Azerbaijan','Gambia','Liberia','Niger','Comoros','Palestinian Territories','Eswatini, Kingdom of','Madagascar','Chad','Yemen','Mauritania','Lesotho','Botswana','Rwanda'])

# %%
# merging again after renaming asterix
df_merge_ctry = df_ctrylist.merge(df_happyrank, on = 'Country', how='outer', indicator=True)
df_merge_ctry
# Out:
#                      Country   RANK      _merge
# 0                Afghanistan  146.0        both
# 1                     Angola    NaN   left_only
# 2                    Albania   90.0        both
# 3                  Argentina   57.0        both
# 4                    Armenia   82.0        both
# ..                       ...    ...         ...
# 209                   Turkey  112.0  right_only
# 210  Palestinian Territories  122.0  right_only
# 211     Eswatini, Kingdom of  125.0  right_only
# 212                 Tanzania  139.0  right_only
# 213                  Lebanon  145.0  right_only
#
# [214 rows x 3 columns]

# %%
df_merge_ctry['_merge'].value_counts(dropna=False)
# Out:
# both          126
# left_only      68
# right_only     20
# Name: _merge, dtype: int64

# %%
# check for countries not merged into df_happyrank
df_filter_ctry_right = df_merge_ctry[df_merge_ctry['_merge'].isin(['right_only'])]
df_filter_ctry_right
# Out:
#                        Country   RANK      _merge
# 194   Taiwan Province of China   26.0  right_only
# 195                  Nicaragua   45.0  right_only
# 196                      Japan   54.0  right_only
# 197                South Korea   59.0  right_only
# 198                    Moldova   62.0  right_only
# 199                    Bolivia   71.0  right_only
# 200                    Vietnam   77.0  right_only
# 201               North Cyprus   79.0  right_only
# 202                     Russia   80.0  right_only
# 203  Hong Kong S.A.R. of China   81.0  right_only
# 204                      Libya   86.0  right_only
# 205                Ivory Coast   88.0  right_only
# 206                       Laos   95.0  right_only
# 207                  Venezuela  108.0  right_only
# 208                       Iran  110.0  right_only
# 209                     Turkey  112.0  right_only
# 210    Palestinian Territories  122.0  right_only
# 211       Eswatini, Kingdom of  125.0  right_only
# ...

# %%
crosstabs = pd.crosstab(df_ctrylist['Country'],df_happyrank['Country'], dropna=False)
crosstabs
# Out:
# Country      Afghanistan  Albania  Algeria  Argentina  Armenia  Australia  \
# Country
# Afghanistan            0        0        0          0        0          0
# Albania                0        0        0          0        0          0
# Algeria                0        0        0          0        0          0
# Angola                 0        0        0          0        0          0
# Anguilla               0        0        0          0        0          0
# ...                  ...      ...      ...        ...      ...        ...
# Uruguay                0        0        0          0        0          0
# Viet Nam               0        0        0          0        0          0
# Yemen                  0        0        0          0        0          0
# Zambia                 0        0        0          0        0          0
# Zimbabwe               0        0        0          0        0          0
#
# Country      Austria  Azerbaijan  Bahrain  Bangladesh  ...  \
# ...

# %%
# renaming more countries in df_happyrank to match with unicef list.
df_happyrank['Country'] = df_happyrank['Country'].replace({
    "South Korea":"Republic of Korea",
    "Moldova":"Republic of Moldova",
    "Bolivia":"Bolivia (Plurinational State of)",
    "Vietnam":"Viet Nam",
    'Russia':'Russian Federation',
    "Ivory Coast":"Côte d'Ivoire",
    "Laos":"Lao People's Democratic Republic",
    'Venezuela':'Venezuela (Bolivarian Republic of)',
    'Iran':'Iran (Islamic Republic of)',
    'Turkey':'Türkiye',
    "Palestinian Territories":"State of Palestine",
    "Eswatini, Kingdom of":"Eswatini",
    "Tanzania":"United Republic of Tanzania"})

# %%
# merging again after renaming based on UNICEF list
df_merge_ctry = df_ctrylist.merge(df_happyrank, on = 'Country', how='outer', indicator=True)
df_merge_ctry
# Out:
#                        Country   RANK      _merge
# 0                  Afghanistan  146.0        both
# 1                       Angola    NaN   left_only
# 2                      Albania   90.0        both
# 3                    Argentina   57.0        both
# 4                      Armenia   82.0        both
# ..                         ...    ...         ...
# 196                      Japan   54.0  right_only
# 197               North Cyprus   79.0  right_only
# 198  Hong Kong S.A.R. of China   81.0  right_only
# 199                      Libya   86.0  right_only
# 200                    Lebanon  145.0  right_only
#
# [201 rows x 3 columns]

# %%
df_merge_ctry['_merge'].value_counts(dropna=False)
# Out:
# both          139
# left_only      55
# right_only      7
# Name: _merge, dtype: int64

# %%
# getting list of countries not merged into df_happyrank. These countries are not in UNICEF list.
df_filter_ctry_right = df_merge_ctry[df_merge_ctry['_merge'].isin(['right_only'])]
df_filter_ctry_right
# Out:
#                        Country   RANK      _merge
# 194   Taiwan Province of China   26.0  right_only
# 195                  Nicaragua   45.0  right_only
# 196                      Japan   54.0  right_only
# 197               North Cyprus   79.0  right_only
# 198  Hong Kong S.A.R. of China   81.0  right_only
# 199                      Libya   86.0  right_only
# 200                    Lebanon  145.0  right_only

# %%
# Export countries not in UNICEF based on Happiness ranking list
df_filter_ctry_right.to_csv(os.path.join(path,'02 Data','Checking Data', 'Countries not in UNICEF-HappyRank.csv'))

# %%
# checking list of countris with no Happiness ranking
df_filter_ctry_left = df_merge_ctry[df_merge_ctry['_merge'].isin(['left_only'])]
df_filter_ctry_left
# Out:
#                               Country  RANK     _merge
# 1                              Angola   NaN  left_only
# 5                             Burundi   NaN  left_only
# 10                             Belize   NaN  left_only
# 13                           Barbados   NaN  left_only
# 15           Central African Republic   NaN  left_only
# 20   Democratic Republic of the Congo   NaN  left_only
# 25                               Cuba   NaN  left_only
# 36                      Guinea-Bissau   NaN  left_only
# 38                             Guyana   NaN  left_only
# 40                              Haiti   NaN  left_only
# 49                           Kiribati   NaN  left_only
# 52                        Saint Lucia   NaN  left_only
# 77                              Sudan   NaN  left_only
# 82              Sao Tome and Principe   NaN  left_only
# 83                           Suriname   NaN  left_only
# 85           Turks and Caicos Islands   NaN  left_only
# ...

# %%
df_happyrank_filter = df_merge_ctry[df_merge_ctry['_merge'].isin(['left_only','both'])]
df_happyrank_filter
# Out:
#                                 Country   RANK     _merge
# 0                           Afghanistan  146.0       both
# 1                                Angola    NaN  left_only
# 2                               Albania   90.0       both
# 3                             Argentina   57.0       both
# 4                               Armenia   82.0       both
# ..                                  ...    ...        ...
# 189                             Vanuatu    NaN  left_only
# 190  Venezuela (Bolivarian Republic of)  108.0       both
# 191                                Niue    NaN  left_only
# 192                             Tokelau    NaN  left_only
# 193                 Trinidad and Tobago    NaN  left_only
#
# [194 rows x 3 columns]

# %% [markdown]
# #input nan values with Not Available. Commented out if not used
# df_happyrank_filter['RANK'].fillna('Not Available', inplace=True)
# df_happyrank_filter

# %% [markdown]
# #### Renaming Columns

# %%
df_happyrank_filter.rename(columns={'RANK':'Happiness_Rank'}, inplace=True)
df_happyrank_filter
# Out:
# C:\Users\Azalia\AppData\Local\Temp\ipykernel_108392\3829214895.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_happyrank_filter.rename(columns={'RANK':'Happiness_Rank'}, inplace=True)
#                                 Country  Happiness_Rank     _merge
# 0                           Afghanistan           146.0       both
# 1                                Angola             NaN  left_only
# 2                               Albania            90.0       both
# 3                             Argentina            57.0       both
# 4                               Armenia            82.0       both
# ..                                  ...             ...        ...
# 189                             Vanuatu             NaN  left_only
# ...

# %%
df_happyrank_clean = df_happyrank_filter.drop(columns = ['_merge'])
df_happyrank_clean
# Out:
#                                 Country  Happiness_Rank
# 0                           Afghanistan           146.0
# 1                                Angola             NaN
# 2                               Albania            90.0
# 3                             Argentina            57.0
# 4                               Armenia            82.0
# ..                                  ...             ...
# 189                             Vanuatu             NaN
# 190  Venezuela (Bolivarian Republic of)           108.0
# 191                                Niue             NaN
# 192                             Tokelau             NaN
# 193                 Trinidad and Tobago             NaN
#
# [194 rows x 2 columns]

# %% [markdown]
# #### Merge Happiness rank to df file

# %%
df_merge = df_concat_del2_clean_gender.merge(df_happyrank_clean, on = 'Country', indicator=True)
df_merge
# Out:
#                   Country                                          Indicator  \
# 0             Afghanistan  Completion rate for children of primary school...
# 1             Afghanistan  Completion rate for children of primary school...
# 2             Afghanistan  Completion rate for youth of upper secondary e...
# 3             Afghanistan  Completion rate for youth of upper secondary e...
# 4             Afghanistan  Completion rate for adolescents of lower secon...
# ...                   ...                                                ...
# 1529               Sweden  Out-of-school rate for youth of upper secondar...
# 1530              Tokelau  Out-of-school rate for youth of upper secondar...
# 1531              Tokelau  Out-of-school rate for youth of upper secondar...
# 1532  Trinidad and Tobago  Out-of-school rate for youth of upper secondar...
# 1533  Trinidad and Tobago  Out-of-school rate for youth of upper secondar...
#
# ...

# %%
df_merge['_merge'].value_counts(dropna=False)
# Out:
# both          1534
# left_only        0
# right_only       0
# Name: _merge, dtype: int64

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1534 entries, 0 to 1533
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          1534 non-null   object
#  1   Indicator        1534 non-null   object
#  2   Gender           1534 non-null   object
#  3   Education_Level  1534 non-null   object
#  4   Wealth_Quintile  1534 non-null   object
#  5   Residence        1534 non-null   object
#  6   Data_Year        1534 non-null   object
#  7   Percentage       1534 non-null   float64
#  8   Data_Source      1534 non-null   object
#  9   Happiness_Rank   1188 non-null   float64
#  10  _merge           1534 non-null   category
# dtypes: category(1), float64(2), object(8)
# memory usage: 133.5+ KB

# %%
df_merge = df_merge.drop(columns = ['_merge'])
df_merge
# Out:
#                   Country                                          Indicator  \
# 0             Afghanistan  Completion rate for children of primary school...
# 1             Afghanistan  Completion rate for children of primary school...
# 2             Afghanistan  Completion rate for youth of upper secondary e...
# 3             Afghanistan  Completion rate for youth of upper secondary e...
# 4             Afghanistan  Completion rate for adolescents of lower secon...
# ...                   ...                                                ...
# 1529               Sweden  Out-of-school rate for youth of upper secondar...
# 1530              Tokelau  Out-of-school rate for youth of upper secondar...
# 1531              Tokelau  Out-of-school rate for youth of upper secondar...
# 1532  Trinidad and Tobago  Out-of-school rate for youth of upper secondar...
# 1533  Trinidad and Tobago  Out-of-school rate for youth of upper secondar...
#
# ...

# %% [markdown]
# Below code is commented out. Not changing the type
#
# df_merge['Happiness_Rank']=df_merge['Happiness_Rank'].astype('int32')

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1534 entries, 0 to 1533
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          1534 non-null   object
#  1   Indicator        1534 non-null   object
#  2   Gender           1534 non-null   object
#  3   Education_Level  1534 non-null   object
#  4   Wealth_Quintile  1534 non-null   object
#  5   Residence        1534 non-null   object
#  6   Data_Year        1534 non-null   object
#  7   Percentage       1534 non-null   float64
#  8   Data_Source      1534 non-null   object
#  9   Happiness_Rank   1188 non-null   float64
# dtypes: float64(2), object(8)
# memory usage: 131.8+ KB

# %%
df_merge
# Out:
#                   Country                                          Indicator  \
# 0             Afghanistan  Completion rate for children of primary school...
# 1             Afghanistan  Completion rate for children of primary school...
# 2             Afghanistan  Completion rate for youth of upper secondary e...
# 3             Afghanistan  Completion rate for youth of upper secondary e...
# 4             Afghanistan  Completion rate for adolescents of lower secon...
# ...                   ...                                                ...
# 1529               Sweden  Out-of-school rate for youth of upper secondar...
# 1530              Tokelau  Out-of-school rate for youth of upper secondar...
# 1531              Tokelau  Out-of-school rate for youth of upper secondar...
# 1532  Trinidad and Tobago  Out-of-school rate for youth of upper secondar...
# 1533  Trinidad and Tobago  Out-of-school rate for youth of upper secondar...
#
# ...

# %% [markdown]
# # 3. Adding additional file #2

# %%
#loading GDP per capita file and Income Group
df_gdpdirty = pd.read_csv(os.path.join(path,'02 Data','Original Data','GDP Per Capita 2021.csv'))
df_incomegrp = pd.read_csv(os.path.join(path,'02 Data','Original Data','Country Income Group.csv'))

# %%
df_gdpdirty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  266 non-null    object
#  1   Country Code  266 non-null    object
#  2   2021          245 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 6.4+ KB

# %%
df_incomegrp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  265 non-null    object
#  1   Region        217 non-null    object
#  2   IncomeGroup   216 non-null    object
#  3   TableName     265 non-null    object
# dtypes: object(4)
# memory usage: 8.4+ KB

# %%
df_gdpdirty
# Out:
#                     Country Name Country Code          2021
# 0                          Aruba          ABW  29342.100860
# 1    Africa Eastern and Southern          AFE   1537.336021
# 2                    Afghanistan          AFG    368.754614
# 3     Africa Western and Central          AFW   1757.030626
# 4                         Angola          AGO   1953.533757
# ..                           ...          ...           ...
# 261                       Kosovo          XKX   5269.783901
# 262                  Yemen, Rep.          YEM           NaN
# 263                 South Africa          ZAF   7055.044776
# 264                       Zambia          ZMB   1137.343633
# 265                     Zimbabwe          ZWE   1773.920411
#
# [266 rows x 3 columns]

# %%
# merge gdp/c and income group files
df_gdpdirty_merge = df_gdpdirty.merge(df_incomegrp,on='Country Code',how='outer', indicator=True)
df_gdpdirty_merge
# Out:
#                     Country Name Country Code          2021  \
# 0                          Aruba          ABW  29342.100860
# 1    Africa Eastern and Southern          AFE   1537.336021
# 2                    Afghanistan          AFG    368.754614
# 3     Africa Western and Central          AFW   1757.030626
# 4                         Angola          AGO   1953.533757
# ..                           ...          ...           ...
# 261                       Kosovo          XKX   5269.783901
# 262                  Yemen, Rep.          YEM           NaN
# 263                 South Africa          ZAF   7055.044776
# 264                       Zambia          ZMB   1137.343633
# 265                     Zimbabwe          ZWE   1773.920411
#
#                          Region          IncomeGroup  \
# 0     Latin America & Caribbean          High income
# 1                           NaN                  NaN
# 2                    South Asia           Low income
# ...

# %%
df_gdpdirty_merge['_merge'].value_counts(dropna=False)
# Out:
# both          265
# left_only       1
# right_only      0
# Name: _merge, dtype: int64

# %%
df_gdpdirty_merge_left = df_gdpdirty_merge[df_gdpdirty_merge['_merge'].isin(['left_only'])]
df_gdpdirty_merge_left
# Out:
#        Country Name Country Code  2021 Region IncomeGroup TableName     _merge
# 110  Not classified          INX   NaN    NaN         NaN       NaN  left_only

# %%
# Remove the above record by creating inverse of this list
df_gdpdirty_merge = df_gdpdirty_merge[~df_gdpdirty_merge['_merge'].isin(['left_only'])]
df_gdpdirty_merge.shape
# Out:
# (265, 7)

# %%
df_gdpdirty_merge['_merge'].value_counts(dropna=False)
# Out:
# both          265
# left_only       0
# right_only      0
# Name: _merge, dtype: int64

# %%
# Remove TableName column (same as Country Column) and _merge column
df_gdpdirty_merge_drop = df_gdpdirty_merge.drop(columns = ['TableName','_merge'])
df_gdpdirty_merge_drop
# Out:
#                     Country Name Country Code          2021  \
# 0                          Aruba          ABW  29342.100860
# 1    Africa Eastern and Southern          AFE   1537.336021
# 2                    Afghanistan          AFG    368.754614
# 3     Africa Western and Central          AFW   1757.030626
# 4                         Angola          AGO   1953.533757
# ..                           ...          ...           ...
# 261                       Kosovo          XKX   5269.783901
# 262                  Yemen, Rep.          YEM           NaN
# 263                 South Africa          ZAF   7055.044776
# 264                       Zambia          ZMB   1137.343633
# 265                     Zimbabwe          ZWE   1773.920411
#
#                          Region          IncomeGroup
# 0     Latin America & Caribbean          High income
# 1                           NaN                  NaN
# 2                    South Asia           Low income
# ...

# %%
# Display missing values of region
df_gdpdirty_merge_regionNaN = df_gdpdirty_merge_drop[df_gdpdirty_merge_drop['Region'].isnull()==True]
df_gdpdirty_merge_regionNaN
# Out:
#                                           Country Name Country Code  \
# 1                          Africa Eastern and Southern          AFE
# 3                           Africa Western and Central          AFW
# 7                                           Arab World          ARB
# 36                      Central Europe and the Baltics          CEB
# 49                              Caribbean small states          CSS
# 61         East Asia & Pacific (excluding high income)          EAP
# 62                          Early-demographic dividend          EAR
# 63                                 East Asia & Pacific          EAS
# 64       Europe & Central Asia (excluding high income)          ECA
# 65                               Europe & Central Asia          ECS
# 68                                           Euro area          EMU
# 73                                      European Union          EUU
# 74            Fragile and conflict affected situations          FCS
# ...

# %%
df_gdpdirty_merge_regionNaN.shape
# Out:
# (48, 5)

# %% [markdown]
# This list contains aggregated values. To remove this list from the df and export this list of aggregates.

# %%
# drop columns before export
df_gdpdirty_merge_regionNaN.drop(columns = ['Region','IncomeGroup'], inplace = True)
df_gdpdirty_merge_regionNaN
# Out:
# C:\Users\Azalia\AppData\Local\Temp\ipykernel_108392\297871357.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdpdirty_merge_regionNaN.drop(columns = ['Region','IncomeGroup'], inplace = True)
#                                           Country Name Country Code  \
# 1                          Africa Eastern and Southern          AFE
# 3                           Africa Western and Central          AFW
# 7                                           Arab World          ARB
# 36                      Central Europe and the Baltics          CEB
# 49                              Caribbean small states          CSS
# 61         East Asia & Pacific (excluding high income)          EAP
# 62                          Early-demographic dividend          EAR
# ...

# %%
# Export dataset for future use
df_gdpdirty_merge_regionNaN.to_csv(os.path.join(path,'02 Data','Prepared Data', 'Aggregated Region GDP.csv'))

# %%
# Creating inverse of the aggregated list to remove the aggregated records
df_gdpdirty_merge = df_gdpdirty_merge_drop[~df_gdpdirty_merge_drop['Region'].isnull()==True]
df_gdpdirty_merge
# Out:
#      Country Name Country Code          2021                      Region  \
# 0           Aruba          ABW  29342.100860   Latin America & Caribbean
# 2     Afghanistan          AFG    368.754614                  South Asia
# 4          Angola          AGO   1953.533757          Sub-Saharan Africa
# 5         Albania          ALB   6492.872012       Europe & Central Asia
# 6         Andorra          AND  42137.327270       Europe & Central Asia
# ..            ...          ...           ...                         ...
# 261        Kosovo          XKX   5269.783901       Europe & Central Asia
# 262   Yemen, Rep.          YEM           NaN  Middle East & North Africa
# 263  South Africa          ZAF   7055.044776          Sub-Saharan Africa
# 264        Zambia          ZMB   1137.343633          Sub-Saharan Africa
# 265      Zimbabwe          ZWE   1773.920411          Sub-Saharan Africa
#
#              IncomeGroup
# 0            High income
# 2             Low income
# ...

# %%
# Checking for other missing values
df_gdpdirty_merge.isnull().sum()
# Out:
# Country Name     0
# Country Code     0
# 2021            20
# Region           0
# IncomeGroup      1
# dtype: int64

# %%
# Display missing values for Income group
df_gdpdirty_merge[df_gdpdirty_merge['IncomeGroup'].isnull()==True]
# Out:
#       Country Name Country Code  2021                     Region IncomeGroup
# 254  Venezuela, RB          VEN   NaN  Latin America & Caribbean         NaN

# %%
# Impute as Not Availabe
df_gdpdirty_merge['IncomeGroup'].fillna('Not Available', inplace=True)
# Checking
df_gdpdirty_merge[df_gdpdirty_merge['IncomeGroup'].isnull()==True]
# Out:
# C:\Users\Azalia\AppData\Local\Temp\ipykernel_108392\3538464344.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdpdirty_merge['IncomeGroup'].fillna('Not Available', inplace=True)
# Empty DataFrame
# Columns: [Country Name, Country Code, 2021, Region, IncomeGroup]
# Index: []

# %%
# Display missing values for 2021
df_gdpdirty_merge[df_gdpdirty_merge['2021'].isnull()==True]
# Out:
#                   Country Name Country Code  2021                      Region  \
# 38             Channel Islands          CHI   NaN       Europe & Central Asia
# 50                        Cuba          CUB   NaN   Latin America & Caribbean
# 69                     Eritrea          ERI   NaN          Sub-Saharan Africa
# 84                   Gibraltar          GIB   NaN       Europe & Central Asia
# 91                   Greenland          GRL   NaN       Europe & Central Asia
# 108                Isle of Man          IMN   NaN       Europe & Central Asia
# 127                     Kuwait          KWT   NaN  Middle East & North Africa
# 137              Liechtenstein          LIE   NaN       Europe & Central Asia
# 147   St. Martin (French part)          MAF   NaN   Latin America & Caribbean
# 164   Northern Mariana Islands          MNP   NaN         East Asia & Pacific
# 193  Korea, Dem. People's Rep.          PRK   NaN         East Asia & Pacific
# ...

# %% [markdown]
# ##### Below code is for changing '2021' nan values with Not Available. Marked Down if not used.
# df_gdpdirty_merge['2021'].fillna('Not Available', inplace=True)

# %%
df_gdpdirty_merge[df_gdpdirty_merge['2021'].isnull()==True]
# Out:
#                   Country Name Country Code  2021                      Region  \
# 38             Channel Islands          CHI   NaN       Europe & Central Asia
# 50                        Cuba          CUB   NaN   Latin America & Caribbean
# 69                     Eritrea          ERI   NaN          Sub-Saharan Africa
# 84                   Gibraltar          GIB   NaN       Europe & Central Asia
# 91                   Greenland          GRL   NaN       Europe & Central Asia
# 108                Isle of Man          IMN   NaN       Europe & Central Asia
# 127                     Kuwait          KWT   NaN  Middle East & North Africa
# 137              Liechtenstein          LIE   NaN       Europe & Central Asia
# 147   St. Martin (French part)          MAF   NaN   Latin America & Caribbean
# 164   Northern Mariana Islands          MNP   NaN         East Asia & Pacific
# 193  Korea, Dem. People's Rep.          PRK   NaN         East Asia & Pacific
# ...

# %%
#Renaming columns
df_gdpdirty_merge.rename(columns={'Country Name':'Country','2021':'GDP_PerCapita','Country Code':'Country_Code','IncomeGroup':'Income_Group'}, inplace=True)
df_gdpdirty_merge
# Out:
# C:\Users\Azalia\AppData\Local\Temp\ipykernel_108392\2520478501.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdpdirty_merge.rename(columns={'Country Name':'Country','2021':'GDP_PerCapita','Country Code':'Country_Code','IncomeGroup':'Income_Group'}, inplace=True)
#           Country Country_Code  GDP_PerCapita                      Region  \
# 0           Aruba          ABW   29342.100860   Latin America & Caribbean
# 2     Afghanistan          AFG     368.754614                  South Asia
# 4          Angola          AGO    1953.533757          Sub-Saharan Africa
# 5         Albania          ALB    6492.872012       Europe & Central Asia
# 6         Andorra          AND   42137.327270       Europe & Central Asia
# ...

# %% [markdown]
# #### Merging country list

# %%
# merge df_gdpdirty_merge countries with df_ctrylist. Outer merge to see full list and if cleaning needs to be done
df_gdp_ctry = df_ctrylist.merge(df_gdpdirty_merge, on = 'Country', how='outer', indicator=True)
df_gdp_ctry
# Out:
#                             Country Country_Code  GDP_PerCapita  \
# 0                       Afghanistan          AFG     368.754614
# 1                            Angola          AGO    1953.533757
# 2                           Albania          ALB    6492.872012
# 3                         Argentina          ARG   10636.120200
# 4                           Armenia          ARM    4966.513471
# ..                              ...          ...            ...
# 241  St. Vincent and the Grenadines          VCT    8666.387041
# 242                   Venezuela, RB          VEN            NaN
# 243           Virgin Islands (U.S.)          VIR            NaN
# 244                         Vietnam          VNM    3756.489121
# 245                     Yemen, Rep.          YEM            NaN
#
#                          Region         Income_Group      _merge
# 0                    South Asia           Low income        both
# 1            Sub-Saharan Africa  Lower middle income        both
# ...

# %%
# Checking merge results
df_gdp_ctry['_merge'].value_counts(dropna=False)
# Out:
# both          165
# right_only     52
# left_only      29
# Name: _merge, dtype: int64

# %%
# Check for right only first for countries not merged, in order to rename countries if needed
df_gdp_right = df_gdp_ctry[df_gdp_ctry['_merge'].isin(['right_only'])]
df_gdp_right
# Out:
#                             Country Country_Code  GDP_PerCapita  \
# 194                           Aruba          ABW   29342.100860
# 195                         Andorra          AND   42137.327270
# 196                  American Samoa          ASM   15743.310760
# 197                    Bahamas, The          BHS   27478.389630
# 198                         Bermuda          BMU  114090.328300
# 199                         Bolivia          BOL    3345.196589
# 200                 Channel Islands          CHI            NaN
# 201                   Cote d'Ivoire          CIV    2549.041297
# 202                Congo, Dem. Rep.          COD     577.209215
# 203                     Congo, Rep.          COG    2290.382891
# 204                         Curacao          CUW   17717.596480
# 205                  Cayman Islands          CYM   86568.769640
# 206                Egypt, Arab Rep.          EGY    3698.834981
# 207                   Faroe Islands          FRO   69010.309800
# ...

# %%
# renaming countries in df_gdp for better match with unicef list.
df_gdpdirty_merge['Country'] = df_gdpdirty_merge['Country'].replace({ 
    "Bolivia":"Bolivia (Plurinational State of)",
    "Cote d'Ivoire":"Côte d'Ivoire",
    "Congo, Dem. Rep.":"Democratic Republic of the Congo",
    'Congo, Rep.':'Congo',
    'Egypt, Arab Rep.':'Egypt',
    'Micronesia, Fed. Sts.':'Micronesia (Federated States of)',
    'Gambia, The':'Gambia',
    'Iran, Islamic Rep.':'Iran (Islamic Republic of)',
    'Kyrgyz Republic':'Kyrgyzstan',
    'St. Kitts and Nevis':'Saint Kitts and Nevis',
    "Korea, Rep.":"Republic of Korea",
    "Lao PDR":"Lao People's Democratic Republic",
    'St. Lucia':'Saint Lucia',
    "Moldova":"Republic of Moldova",
    "Korea, Dem. People's Rep.":"Democratic People's Republic of Korea",
    'West Bank and Gaza':'State of Palestine',
    'Slovak Republic':'Slovakia',
    'Turkiye':'Türkiye',
    "Tanzania":"United Republic of Tanzania",
    'St. Vincent and the Grenadines':'Saint Vincent and the Grenadines',
    'Venezuela, RB':'Venezuela (Bolivarian Republic of)',
    "Vietnam":"Viet Nam",
    'Yemen, Rep.':'Yemen'
    })
# Out:
# C:\Users\Azalia\AppData\Local\Temp\ipykernel_108392\497461630.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdpdirty_merge['Country'] = df_gdpdirty_merge['Country'].replace({

# %%
# merging again after update
df_gdp_ctry = df_ctrylist.merge(df_gdpdirty_merge, on = 'Country', how='outer', indicator=True)
df_gdp_ctry
# Out:
#                        Country Country_Code  GDP_PerCapita  \
# 0                  Afghanistan          AFG     368.754614
# 1                       Angola          AGO    1953.533757
# 2                      Albania          ALB    6492.872012
# 3                    Argentina          ARG   10636.120200
# 4                      Armenia          ARM    4966.513471
# ..                         ...          ...            ...
# 218           French Polynesia          PYF   19914.603510
# 219                    Somalia          SOM     446.981560
# 220  Sint Maarten (Dutch part)          SXM            NaN
# 221       Syrian Arab Republic          SYR            NaN
# 222      Virgin Islands (U.S.)          VIR            NaN
#
#                          Region         Income_Group      _merge
# 0                    South Asia           Low income        both
# 1            Sub-Saharan Africa  Lower middle income        both
# ...

# %%
# Checking merge results after update
df_gdp_ctry['_merge'].value_counts(dropna=False)
# Out:
# both          188
# right_only     29
# left_only       6
# Name: _merge, dtype: int64

# %%
# Check for right only first for countries not merged, in order to rename countries if needed
df_gdp_right = df_gdp_ctry[df_gdp_ctry['_merge'].isin(['right_only'])]
df_gdp_right
# Out:
#                        Country Country_Code  GDP_PerCapita  \
# 194                      Aruba          ABW   29342.100860
# 195                    Andorra          AND   42137.327270
# 196             American Samoa          ASM   15743.310760
# 197               Bahamas, The          BHS   27478.389630
# 198                    Bermuda          BMU  114090.328300
# 199            Channel Islands          CHI            NaN
# 200                    Curacao          CUW   17717.596480
# 201             Cayman Islands          CYM   86568.769640
# 202              Faroe Islands          FRO   69010.309800
# 203                  Gibraltar          GIB            NaN
# 204                  Greenland          GRL            NaN
# 205                       Guam          GUM   35904.863550
# 206       Hong Kong SAR, China          HKG   49800.542410
# 207                Isle of Man          IMN            NaN
# 208                      Japan          JPN   39312.660370
# ...

# %%
# Export countries not in UNICEF based on Happiness ranking list
df_gdp_right.to_csv(os.path.join(path,'02 Data','Checking Data', 'Countries not in UNICEF-GDP.csv'))

# %%
# Check for left only for countries not in GDP list for info
df_gdp_left = df_gdp_ctry[df_gdp_ctry['_merge'].isin(['left_only'])]
df_gdp_left
# Out:
#           Country Country_Code  GDP_PerCapita Region Income_Group     _merge
# 107      Anguilla          NaN            NaN    NaN          NaN  left_only
# 121  Cook Islands          NaN            NaN    NaN          NaN  left_only
# 137      Holy See          NaN            NaN    NaN          NaN  left_only
# 156    Montserrat          NaN            NaN    NaN          NaN  left_only
# 191          Niue          NaN            NaN    NaN          NaN  left_only
# 192       Tokelau          NaN            NaN    NaN          NaN  left_only

# %%
# creating filter of data for both and left only
df_gdp = df_gdp_ctry[df_gdp_ctry['_merge'].isin(['left_only','both'])]
df_gdp
# Out:
#                                 Country Country_Code  GDP_PerCapita  \
# 0                           Afghanistan          AFG     368.754614
# 1                                Angola          AGO    1953.533757
# 2                               Albania          ALB    6492.872012
# 3                             Argentina          ARG   10636.120200
# 4                               Armenia          ARM    4966.513471
# ..                                  ...          ...            ...
# 189                             Vanuatu          VUT    2996.621062
# 190  Venezuela (Bolivarian Republic of)          VEN            NaN
# 191                                Niue          NaN            NaN
# 192                             Tokelau          NaN            NaN
# 193                 Trinidad and Tobago          TTO   16032.502770
#
#                         Region         Income_Group     _merge
# 0                   South Asia           Low income       both
# ...

# %% [markdown]
# ##### Below code is for changing GDP nan values with Not Available. Marked Down if not used.
# df_gdp.fillna({'Country_Code':'Not Available','GDP_PerCapita':'Not Available','Region':'Not Available','Income_Group':'Not Available'}, inplace=True)
# df_gdp

# %%
# delete _merge columns
df_gdp.drop(columns = ['_merge'], inplace=True)
df_gdp
# Out:
# C:\Users\Azalia\AppData\Local\Temp\ipykernel_108392\3379106438.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp.drop(columns = ['_merge'], inplace=True)
#                                 Country Country_Code  GDP_PerCapita  \
# 0                           Afghanistan          AFG     368.754614
# 1                                Angola          AGO    1953.533757
# 2                               Albania          ALB    6492.872012
# 3                             Argentina          ARG   10636.120200
# 4                               Armenia          ARM    4966.513471
# ..                                  ...          ...            ...
# 189                             Vanuatu          VUT    2996.621062
# 190  Venezuela (Bolivarian Republic of)          VEN            NaN
# ...

# %% [markdown]
# ### Merging GDP file with main df

# %%
df_merge
# Out:
#                   Country                                          Indicator  \
# 0             Afghanistan  Completion rate for children of primary school...
# 1             Afghanistan  Completion rate for children of primary school...
# 2             Afghanistan  Completion rate for youth of upper secondary e...
# 3             Afghanistan  Completion rate for youth of upper secondary e...
# 4             Afghanistan  Completion rate for adolescents of lower secon...
# ...                   ...                                                ...
# 1529               Sweden  Out-of-school rate for youth of upper secondar...
# 1530              Tokelau  Out-of-school rate for youth of upper secondar...
# 1531              Tokelau  Out-of-school rate for youth of upper secondar...
# 1532  Trinidad and Tobago  Out-of-school rate for youth of upper secondar...
# 1533  Trinidad and Tobago  Out-of-school rate for youth of upper secondar...
#
# ...

# %%
df_merge_gdp = df_merge.merge(df_gdp, on ='Country', indicator=True)
df_merge_gdp
# Out:
#                   Country                                          Indicator  \
# 0             Afghanistan  Completion rate for children of primary school...
# 1             Afghanistan  Completion rate for children of primary school...
# 2             Afghanistan  Completion rate for youth of upper secondary e...
# 3             Afghanistan  Completion rate for youth of upper secondary e...
# 4             Afghanistan  Completion rate for adolescents of lower secon...
# ...                   ...                                                ...
# 1529               Sweden  Out-of-school rate for youth of upper secondar...
# 1530              Tokelau  Out-of-school rate for youth of upper secondar...
# 1531              Tokelau  Out-of-school rate for youth of upper secondar...
# 1532  Trinidad and Tobago  Out-of-school rate for youth of upper secondar...
# 1533  Trinidad and Tobago  Out-of-school rate for youth of upper secondar...
#
# ...

# %%
df_merge_gdp['_merge'].value_counts(dropna=False)
# Out:
# both          1534
# left_only        0
# right_only       0
# Name: _merge, dtype: int64

# %%
df_merge_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1534 entries, 0 to 1533
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          1534 non-null   object
#  1   Indicator        1534 non-null   object
#  2   Gender           1534 non-null   object
#  3   Education_Level  1534 non-null   object
#  4   Wealth_Quintile  1534 non-null   object
#  5   Residence        1534 non-null   object
#  6   Data_Year        1534 non-null   object
#  7   Percentage       1534 non-null   float64
#  8   Data_Source      1534 non-null   object
#  9   Happiness_Rank   1188 non-null   float64
#  10  Country_Code     1518 non-null   object
#  11  GDP_PerCapita    1444 non-null   float64
#  12  Region           1518 non-null   object
#  13  Income_Group     1518 non-null   object
#  14  _merge           1534 non-null   category
# dtypes: category(1), float64(3), object(11)
# memory usage: 181.4+ KB

# %%
df_merge_gdp.describe()
# Out:
#         Percentage  Happiness_Rank  GDP_PerCapita
# count  1534.000000     1188.000000    1444.000000
# mean     36.972820       82.383838   10988.918348
# std      33.389832       40.505535   17882.644838
# min       0.000000        1.000000     221.477676
# 25%       6.657477       49.000000    1666.932734
# 50%      25.685541       87.000000    4775.377454
# 75%      63.998851      117.000000   10045.680500
# max     100.000000      146.000000  133590.147000

# %%
# delete _merge columns
df_merge_gdp.drop(columns = ['_merge'], inplace=True)
df_merge_gdp
# Out:
#                   Country                                          Indicator  \
# 0             Afghanistan  Completion rate for children of primary school...
# 1             Afghanistan  Completion rate for children of primary school...
# 2             Afghanistan  Completion rate for youth of upper secondary e...
# 3             Afghanistan  Completion rate for youth of upper secondary e...
# 4             Afghanistan  Completion rate for adolescents of lower secon...
# ...                   ...                                                ...
# 1529               Sweden  Out-of-school rate for youth of upper secondar...
# 1530              Tokelau  Out-of-school rate for youth of upper secondar...
# 1531              Tokelau  Out-of-school rate for youth of upper secondar...
# 1532  Trinidad and Tobago  Out-of-school rate for youth of upper secondar...
# 1533  Trinidad and Tobago  Out-of-school rate for youth of upper secondar...
#
# ...

# %%
# Export Data
df_merge_gdp.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'State_of_Education.csv'), index=False)
